# %%
import log
# %matplotlib inline
# cifar10 has the following layers
# data, conv1, pool1, relu1, norm1, conv2, relu2, pool2, norm2, conv3, relu3, pool3, 'inner product'

# %%
log.scatter('logs/Jeston_TK1/cifar10_cifarnet.csv', ['GPU', 'CPU'], ['data'])
# the rate of increase is much slower when running in GPU
# Out:
# File already exists, will append onwards

# %%
log.scatter('logs/Jeston_TK1/cifar10_cifarnet.csv', ['GPU'], ['data'])
# a closer look at GPU inference time increasing rate
# GPU seems to converge??
# Out:
# File already exists, will append onwards

# %%
log.scatter('logs/Jeston_TK1/cifar10_cifarnet.csv', ['GPU'], ['data', 'conv1'])
log.scatter('logs/Chihang/cifarnet_cifar10.csv', ['GPU'], ['data', 'conv1'])
# in my laptop, the normalization step seems to take a very long time
# Out:
# File already exists, will append onwards
# File already exists, will append onwards

# %%
log.scatter('logs/Jeston_TK1/cifar10_cifarnet.csv', ['CPU'], ['data', 'conv1'])
log.scatter('logs/Chihang/cifarnet_cifar10.csv', ['CPU'], ['data', 'conv1'])
# data normalization takes almost no time when running in CPU
# Out:
# File already exists, will append onwards
# File already exists, will append onwards

# %%
log.scatter('logs/Chihang/cifarnet_cifar10.csv', ['GPU'], ['conv1', 'conv2', 'conv3'])
log.scatter('logs/Jeston_TK1/cifar10_cifarnet.csv', ['GPU'], ['conv1', 'conv2', 'conv3'])
# inference time from conv-layer 1,2,3 respectively
# Out:
# File already exists, will append onwards
# File already exists, will append onwards

# %%
log.scatter('logs/Chihang/lenet_mnist.csv', ['GPU', 'CPU'], ['data', 'conv1'])
log.scatter('logs/Jeston_TK1/mnist_lenet.csv', ['GPU', 'CPU'], ['data', 'conv1'])
# Out:
# File already exists, will append onwards
# File already exists, will append onwards

# %%
log.scatter('logs/Jeston_TK1/mnist_lenet.csv', ['CPU'], ['mean step time', 'data'])
log.scatter('logs/Jeston_TK1/mnist_lenet.csv', ['GPU'], ['mean step time', 'data'])
# mean_step_time includes the back-propagation, which can be seen from below takes a long time
# Out:
# File already exists, will append onwards
# File already exists, will append onwards
